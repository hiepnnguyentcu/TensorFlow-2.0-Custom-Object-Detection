# %% [markdown]
# <a href="https://colab.research.google.com/github/hiepnnguyentcu/TensorFlow-2.0-Custom-Object-Detection/blob/main/TensorFlow_2_0_Custom_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# ## **Cloning TFOD 2.0 Github**

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 85559, done.
# remote: Counting objects: 100% (1158/1158), done.
# remote: Compressing objects: 100% (453/453), done.
# remote: Total 85559 (delta 712), reused 1116 (delta 699), pack-reused 84401
# Receiving objects: 100% (85559/85559), 598.66 MiB | 35.68 MiB/s, done.
# Resolving deltas: 100% (61214/61214), done.

# %%
pwd
# Out:
# '/content'

# %%
cd /content/models/research
# Out:
# /content/models/research

# %%
pwd
# Out:
# '/content/models/research'

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 22.23 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
cd cocoapi/PythonAPI
# Out:
# /content/models/research/cocoapi/PythonAPI

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.10/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/models/research/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-cpython-310
# creating build/temp.linux-x86_64-cpython-310/pycocotools
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/numpy/core/include -I../common -I/usr/include/python3.10 -c ../common/maskApi.c -o build/temp.linux-x86_64-cpython-310/../common/maskApi.o -Wno-cpp -Wno-unused-function -std=c99
# ../common/maskApi.c: In function ‘rleDecode’:
# ../common/maskApi.c:46:7: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#    46 |       for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#       |       ^~~
# ../common/maskApi.c:46:49: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#    46 |       for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#       |                                                 ^
# ../common/maskApi.c: In function ‘rleFrPoly’:
# ../common/maskApi.c:166:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   166 |   for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#       |   ^~~
# ../common/maskApi.c:166:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   166 |   for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#       |                                                      ^
# ../common/maskApi.c:167:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   167 |   for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#       |   ^~~
# ../common/maskApi.c:167:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   167 |   for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#       |                                                      ^
# ../common/maskApi.c: In function ‘rleToString’:
# ../common/maskApi.c:212:7: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   212 |       if(more) c |= 0x20; c+=48; s[p++]=c;
#       |       ^~
# ../common/maskApi.c:212:27: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   212 |       if(more) c |= 0x20; c+=48; s[p++]=c;
#       |                           ^
# ../common/maskApi.c: In function ‘rleFrString’:
# ../common/maskApi.c:220:3: warning: this ‘while’ clause does not guard... [-Wmisleading-indentation]
#   220 |   while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#       |   ^~~~~
# ../common/maskApi.c:220:22: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘while’
#   220 |   while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#       |                      ^~~~
# ../common/maskApi.c:228:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   228 |     if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#       |     ^~
# ../common/maskApi.c:228:34: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   228 |     if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#       |                                  ^~~~
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/numpy/core/include -I../common -I/usr/include/python3.10 -c pycocotools/_mask.c -o build/temp.linux-x86_64-cpython-310/pycocotools/_mask.o -Wno-cpp -Wno-unused-function -std=c99
# creating build/lib.linux-x86_64-cpython-310
# creating build/lib.linux-x86_64-cpython-310/pycocotools
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-310/../common/maskApi.o build/temp.linux-x86_64-cpython-310/pycocotools/_mask.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-310/pycocotools/_mask.cpython-310-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-cpython-310/pycocotools/_mask.cpython-310-x86_64-linux-gnu.so -> pycocotools
# rm -rf build

# %%
cp -r pycocotools /content/models/research

# %% [markdown]
# ### Install the Object Detection API

# %%
cd ..
# Out:
# /content/models/research/cocoapi

# %%
cd ..
# Out:
# /content/models/research

# %%
cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/models/research
#   Preparing metadata (setup.py) ... done
# Collecting avro-python3 (from object-detection==0.1)
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting apache-beam (from object-detection==0.1)
#   Downloading apache_beam-2.47.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 101.3 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (8.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (0.29.34)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (0.6.0.post1)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.0.6)
# Collecting lvis (from object-detection==0.1)
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.5.3)
# Collecting tf-models-official>=2.5.1 (from object-detection==0.1)
#   Downloading tf_models_official-2.12.0-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 92.8 MB/s eta 0:00:00
# Collecting tensorflow_io (from object-detection==0.1)
#   Downloading tensorflow_io-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.0/28.0 MB 62.9 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.12.0)
# Collecting pyparsing==2.4.7 (from object-detection==0.1)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.2 MB/s eta 0:00:00
# Collecting sacrebleu<=2.2.0 (from object-detection==0.1)
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 14.4 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.10.31)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.22.4)
# Collecting colorama (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.84.0)
# Collecting immutabledict (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading immutabledict-2.2.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.13)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Collecting pyyaml<6.0,>=5.1 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading PyYAML-5.4.1.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 20.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sentencepiece (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.4 MB/s eta 0:00:00
# Collecting seqeval (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow-addons (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 46.3 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.2)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.13.0)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_model_optimization-0.7.4-py2.py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 24.2 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.12.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_text-2.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 98.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow~=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2022.7.1)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Collecting crcmod<2.0,>=1.7 (from apache-beam->object-detection==0.1)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting orjson<4.0 (from apache-beam->object-detection==0.1)
#   Downloading orjson-3.8.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 14.7 MB/s eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam->object-detection==0.1)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 17.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Collecting fastavro<2,>=0.23.6 (from apache-beam->object-detection==0.1)
#   Downloading fastavro-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 107.7 MB/s eta 0:00:00
# Collecting fasteners<1.0,>=0.3 (from apache-beam->object-detection==0.1)
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.54.0)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam->object-detection==0.1)
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: httplib2<0.22.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Collecting objsize<0.7.0,>=0.6.1 (from apache-beam->object-detection==0.1)
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam->object-detection==0.1)
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 48.1 MB/s eta 0:00:00
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Requirement already satisfied: protobuf<4.23.0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Collecting zstandard<1,>=0.18.0 (from apache-beam->object-detection==0.1)
#   Downloading zstandard-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 106.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (23.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.15)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (67.7.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Collecting numpy>=1.17 (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 74.2 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.3)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.13.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.40.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.12.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection, avro-python3, crcmod, dill, pyyaml, seqeval, docopt
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696986 sha256=159d16cf496b3c1ad96bcf492e49ed43c72c47ed5d7d2f8f6bba8ee3ff85bba6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vvd6989u/wheels/53/dd/70/2de274d6c443c69d367bd6a5606f95e5a6df61aacf1435ec0d
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=43994 sha256=d2d1f80783084e0088b0ceaf08a986553216db07d277e688bdf958f2c700d18f
#   Stored in directory: /root/.cache/pip/wheels/bc/85/62/6cdd81c56f923946b401cecff38055b94c9b766927f7d8ca82
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=37093 sha256=b3c8c1e08d9a5dac2d30f1a5b4151081a8b8527910102ff8806db09d47189026
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78545 sha256=af537c180b81b675ded0768b754532056a598fe8a299ead6434603f26417735f
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for pyyaml (pyproject.toml) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.4.1-cp310-cp310-linux_x86_64.whl size=45658 sha256=8c56a6d9a984cfdfcc41a1d87a6904d9050e4a338c0853a73884e029936a4280
#   Stored in directory: /root/.cache/pip/wheels/c7/0d/22/696ee92245ad710f506eee79bb05c740d8abccd3ecdb778683
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16165 sha256=035071bc8791fe83915c46f11f20c414a8a7114d21bda04061bcb2a935c8e1a0
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=ddf264da88c61b92e14f78586adaad6367625e5f9c504f835b5043a7eb00bce8
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built object-detection avro-python3 crcmod dill pyyaml seqeval docopt
# Installing collected packages: sentencepiece, docopt, crcmod, zstandard, typeguard, tensorflow_io, pyyaml, pyparsing, portalocker, orjson, objsize, numpy, immutabledict, fasteners, fastavro, dnspython, dill, colorama, avro-python3, tensorflow-model-optimization, tensorflow-addons, sacrebleu, pymongo, hdfs, apache-beam, seqeval, lvis, tensorflow-text, tf-models-official, object-detection
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# Successfully installed apache-beam-2.47.0 avro-python3-1.10.2 colorama-0.4.6 crcmod-1.7 dill-0.3.1.1 dnspython-2.3.0 docopt-0.6.2 fastavro-1.7.4 fasteners-0.18 hdfs-2.7.0 immutabledict-2.2.4 lvis-0.5.3 numpy-1.23.5 object-detection-0.1 objsize-0.6.1 orjson-3.8.12 portalocker-2.7.0 pymongo-4.3.3 pyparsing-2.4.7 pyyaml-5.4.1 sacrebleu-2.2.0 sentencepiece-0.1.99 seqeval-1.2.2 tensorflow-addons-0.20.0 tensorflow-model-optimization-0.7.4 tensorflow-text-2.12.1 tensorflow_io-0.32.0 tf-models-official-2.12.0 typeguard-2.13.3 zstandard-0.21.0

# %%
# From within TensorFlow/models/research/
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2023-05-18 15:50:05.167500: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# Running tests under Python 3.10.11: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-05-18 15:50:12.744460: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.814400 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.968131 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.970853 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.974737 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.984270 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.986751 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.990322 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.992956 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.996797 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:12.999145 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.001703 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.005449 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.007861 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.012463 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.014869 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.019008 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.021288 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.025087 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.027636 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.030175 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.034288 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.038149 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.044907 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.048491 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.053309 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.055786 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.060028 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.062484 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.065157 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.069119 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.071629 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.076489 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.078918 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.083461 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.085964 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.089687 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.092271 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.094940 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.098746 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.101185 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.105655 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.107941 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.111930 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.114455 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.118345 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.120855 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.123438 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.127152 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.130224 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.134163 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.136660 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.141157 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.144058 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.147829 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.150097 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.154247 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.156769 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.160517 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.162894 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.166726 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.169142 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.171792 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.177782 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.180080 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.185492 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.188844 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.194193 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.196623 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.200100 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.202419 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.206620 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.209094 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.212898 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.215217 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.217630 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.222635 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.224926 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.228501 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.230855 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.234965 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.240375 140174419343168 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.284634 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.289645 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.293320 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.296960 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.303270 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.305737 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.309429 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.312692 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.316739 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.319199 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.321814 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.325716 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0518 15:50:13.328103 140174419343168 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# ...
# I0518 15:50:32.531017 140174419343168 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0518 15:50:32.531167 140174419343168 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0518 15:50:32.531233 140174419343168 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0518 15:50:32.532984 140174419343168 efficientnet_model.py:143] round_filter input=32 output=48
# I0518 15:50:32.550551 140174419343168 efficientnet_model.py:143] round_filter input=32 output=48
# I0518 15:50:32.550654 140174419343168 efficientnet_model.py:143] round_filter input=16 output=24
# I0518 15:50:32.760341 140174419343168 efficientnet_model.py:143] round_filter input=16 output=24
# I0518 15:50:32.760515 140174419343168 efficientnet_model.py:143] round_filter input=24 output=40
# I0518 15:50:33.200261 140174419343168 efficientnet_model.py:143] round_filter input=24 output=40
# I0518 15:50:33.200447 140174419343168 efficientnet_model.py:143] round_filter input=40 output=64
# I0518 15:50:33.681192 140174419343168 efficientnet_model.py:143] round_filter input=40 output=64
# I0518 15:50:33.681370 140174419343168 efficientnet_model.py:143] round_filter input=80 output=128
# I0518 15:50:34.325044 140174419343168 efficientnet_model.py:143] round_filter input=80 output=128
# I0518 15:50:34.325214 140174419343168 efficientnet_model.py:143] round_filter input=112 output=176
# I0518 15:50:34.991050 140174419343168 efficientnet_model.py:143] round_filter input=112 output=176
# I0518 15:50:34.991208 140174419343168 efficientnet_model.py:143] round_filter input=192 output=304
# I0518 15:50:36.211627 140174419343168 efficientnet_model.py:143] round_filter input=192 output=304
# I0518 15:50:36.219568 140174419343168 efficientnet_model.py:143] round_filter input=320 output=512
# I0518 15:50:36.659421 140174419343168 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0518 15:50:36.698089 140174419343168 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0518 15:50:36.779315 140174419343168 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0518 15:50:36.779478 140174419343168 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0518 15:50:36.779550 140174419343168 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0518 15:50:36.781287 140174419343168 efficientnet_model.py:143] round_filter input=32 output=56
# I0518 15:50:36.803463 140174419343168 efficientnet_model.py:143] round_filter input=32 output=56
# I0518 15:50:36.803615 140174419343168 efficientnet_model.py:143] round_filter input=16 output=32
# I0518 15:50:37.128046 140174419343168 efficientnet_model.py:143] round_filter input=16 output=32
# I0518 15:50:37.130564 140174419343168 efficientnet_model.py:143] round_filter input=24 output=40
# I0518 15:50:37.861318 140174419343168 efficientnet_model.py:143] round_filter input=24 output=40
# I0518 15:50:37.861546 140174419343168 efficientnet_model.py:143] round_filter input=40 output=72
# I0518 15:50:38.416162 140174419343168 efficientnet_model.py:143] round_filter input=40 output=72
# I0518 15:50:38.416330 140174419343168 efficientnet_model.py:143] round_filter input=80 output=144
# I0518 15:50:39.559377 140174419343168 efficientnet_model.py:143] round_filter input=80 output=144
# I0518 15:50:39.559744 140174419343168 efficientnet_model.py:143] round_filter input=112 output=200
# I0518 15:50:40.609958 140174419343168 efficientnet_model.py:143] round_filter input=112 output=200
# I0518 15:50:40.610137 140174419343168 efficientnet_model.py:143] round_filter input=192 output=344
# I0518 15:50:42.074539 140174419343168 efficientnet_model.py:143] round_filter input=192 output=344
# I0518 15:50:42.074745 140174419343168 efficientnet_model.py:143] round_filter input=320 output=576
# I0518 15:50:42.503634 140174419343168 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0518 15:50:42.564095 140174419343168 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0518 15:50:42.730306 140174419343168 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0518 15:50:42.731636 140174419343168 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0518 15:50:42.731754 140174419343168 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0518 15:50:42.738835 140174419343168 efficientnet_model.py:143] round_filter input=32 output=64
# I0518 15:50:42.774841 140174419343168 efficientnet_model.py:143] round_filter input=32 output=64
# I0518 15:50:42.774997 140174419343168 efficientnet_model.py:143] round_filter input=16 output=32
# I0518 15:50:43.225180 140174419343168 efficientnet_model.py:143] round_filter input=16 output=32
# I0518 15:50:43.225381 140174419343168 efficientnet_model.py:143] round_filter input=24 output=48
# I0518 15:50:44.179406 140174419343168 efficientnet_model.py:143] round_filter input=24 output=48
# I0518 15:50:44.179620 140174419343168 efficientnet_model.py:143] round_filter input=40 output=80
# I0518 15:50:45.156307 140174419343168 efficientnet_model.py:143] round_filter input=40 output=80
# I0518 15:50:45.156521 140174419343168 efficientnet_model.py:143] round_filter input=80 output=160
# I0518 15:50:46.536105 140174419343168 efficientnet_model.py:143] round_filter input=80 output=160
# I0518 15:50:46.536316 140174419343168 efficientnet_model.py:143] round_filter input=112 output=224
# I0518 15:50:47.850292 140174419343168 efficientnet_model.py:143] round_filter input=112 output=224
# I0518 15:50:47.850461 140174419343168 efficientnet_model.py:143] round_filter input=192 output=384
# I0518 15:50:49.027999 140174419343168 efficientnet_model.py:143] round_filter input=192 output=384
# I0518 15:50:49.028155 140174419343168 efficientnet_model.py:143] round_filter input=320 output=640
# I0518 15:50:49.408080 140174419343168 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0518 15:50:49.445813 140174419343168 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 31.9s
# I0518 15:50:49.553663 140174419343168 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 31.9s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0518 15:50:49.581129 140174419343168 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0518 15:50:49.582819 140174419343168 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0518 15:50:49.583354 140174419343168 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0518 15:50:49.584696 140174419343168 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0518 15:50:49.586077 140174419343168 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0518 15:50:49.586516 140174419343168 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0518 15:50:49.587414 140174419343168 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 39.673s
#
# OK (skipped=1)

# %%
cd /content/training_demo/pre_trained_models
# Out:
# /content/training_demo/pre_trained_models

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Out:
# --2023-05-18 16:11:00--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.251.161.128, 2607:f8b0:4001:c5c::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.251.161.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386527459 (369M) [application/x-tar]
# Saving to: ‘ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz’
#
# ssd_resnet101_v1_fp 100%[===================>] 368.62M   214MB/s    in 1.7s
#
# 2023-05-18 16:11:02 (214 MB/s) - ‘ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz’ saved [386527459/386527459]

# %%
# !tar -xvf ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Out:
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/checkpoint
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/pipeline.config
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/saved_model.pb
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/assets/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %%
pwd
# Out:
# '/content/training_demo/pre_trained_models'

# %%
cd /content/training_demo
# Out:
# /content/training_demo

# %%
ls
# Out:
# annotations/         export_tflite_graph_tf2.py  model_main_tf2.py
# exported_models/     generate_tfrecord.py        models/
# exporter_main_v2.py  images/                     pre_trained_models/

# %%
# Create train data:
# !python generate_tfrecord.py -x /content/training_demo/images/train -l /content/training_demo/annotations/label_map.pbtxt -o /content/training_demo/annotations/train.record

# Create test data:
# !python generate_tfrecord.py -x /content/training_demo/images/test -l /content/training_demo/annotations/label_map.pbtxt -o /content/training_demo/annotations/test.record
# Out:
# Successfully created the TFRecord file: /content/training_demo/annotations/train.record
# Successfully created the TFRecord file: /content/training_demo/annotations/test.record

# %%
pwd
# Out:
# '/content/training_demo'

# %%
ls
# Out:
# annotations/         export_tflite_graph_tf2.py  model_main_tf2.py
# exported_models/     generate_tfrecord.py        models/
# exporter_main_v2.py  images/                     pre_trained_models/

# %%
# !python model_main_tf2.py --model_dir=/content/training_demo/models/my_ssd_resnet101_v1_fpn --pipeline_config_path=/content/training_demo/models/my_ssd_resnet101_v1_fpn/pipeline.config
# Out:
# 2023-05-18 16:42:59.832672: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2023-05-18 16:43:09.403971: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0518 16:43:09.443829 140640281061184 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0518 16:43:09.449408 140640281061184 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0518 16:43:09.449594 140640281061184 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0518 16:43:09.681883 140640281061184 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/training_demo/annotations/train.record']
# I0518 16:43:09.689685 140640281061184 dataset_builder.py:162] Reading unweighted datasets: ['/content/training_demo/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/training_demo/annotations/train.record']
# I0518 16:43:09.689883 140640281061184 dataset_builder.py:79] Reading record datasets for input file: ['/content/training_demo/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0518 16:43:09.689970 140640281061184 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0518 16:43:09.690030 140640281061184 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0518 16:43:09.698833 140640281061184 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0518 16:43:09.721651 140640281061184 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0518 16:43:15.681204 140640281061184 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0518 16:43:18.365043 140640281061184 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0518 16:43:20.065544 140640281061184 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# W0518 16:43:23.573248 140640281061184 module_wrapper.py:149] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0518 16:43:33.765744 140635259238144 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0518 16:43:45.287486 140635259238144 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.974071 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.977703 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.978987 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.980202 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.984250 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.985273 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.986323 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.987339 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.991257 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0518 16:44:05.992266 140640281061184 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0518 16:44:08.295233 140635365431040 deprecation.py:569] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0518 16:44:10.157616 140635365431040 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0518 16:44:20.782000 140635365431040 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0518 16:44:29.921306 140635365431040 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0518 16:44:40.644209 140635365431040 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2023-05-18 16:45:16.160177: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-18 16:45:16.160273: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-18 16:45:16.213373: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-18 16:45:16.224581: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# INFO:tensorflow:Step 100 per-step time 2.463s
# I0518 16:48:14.296530 140640281061184 model_lib_v2.py:705] Step 100 per-step time 2.463s
# INFO:tensorflow:{'Loss/classification_loss': 0.22811744,
#  'Loss/localization_loss': 0.071466856,
#  'Loss/regularization_loss': 0.4208487,
#  'Loss/total_loss': 0.720433,
#  'learning_rate': 0.014666351}
# I0518 16:48:14.297019 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.22811744,
#  'Loss/localization_loss': 0.071466856,
#  'Loss/regularization_loss': 0.4208487,
#  'Loss/total_loss': 0.720433,
#  'learning_rate': 0.014666351}
# INFO:tensorflow:Step 200 per-step time 1.766s
# I0518 16:51:10.825043 140640281061184 model_lib_v2.py:705] Step 200 per-step time 1.766s
# INFO:tensorflow:{'Loss/classification_loss': 0.14016552,
#  'Loss/localization_loss': 0.047015544,
#  'Loss/regularization_loss': 0.4164312,
#  'Loss/total_loss': 0.60361224,
#  'learning_rate': 0.0159997}
# I0518 16:51:10.825487 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.14016552,
#  'Loss/localization_loss': 0.047015544,
#  'Loss/regularization_loss': 0.4164312,
#  'Loss/total_loss': 0.60361224,
#  'learning_rate': 0.0159997}
# INFO:tensorflow:Step 300 per-step time 1.764s
# I0518 16:54:07.203738 140640281061184 model_lib_v2.py:705] Step 300 per-step time 1.764s
# INFO:tensorflow:{'Loss/classification_loss': 0.11749186,
#  'Loss/localization_loss': 0.0191196,
#  'Loss/regularization_loss': 0.41152164,
#  'Loss/total_loss': 0.54813313,
#  'learning_rate': 0.01733305}
# I0518 16:54:07.204095 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.11749186,
#  'Loss/localization_loss': 0.0191196,
#  'Loss/regularization_loss': 0.41152164,
#  'Loss/total_loss': 0.54813313,
#  'learning_rate': 0.01733305}
# INFO:tensorflow:Step 400 per-step time 1.761s
# I0518 16:57:03.344606 140640281061184 model_lib_v2.py:705] Step 400 per-step time 1.761s
# INFO:tensorflow:{'Loss/classification_loss': 0.098208226,
#  'Loss/localization_loss': 0.01569143,
#  'Loss/regularization_loss': 0.40617675,
#  'Loss/total_loss': 0.5200764,
#  'learning_rate': 0.0186664}
# I0518 16:57:03.344962 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.098208226,
#  'Loss/localization_loss': 0.01569143,
#  'Loss/regularization_loss': 0.40617675,
#  'Loss/total_loss': 0.5200764,
#  'learning_rate': 0.0186664}
# INFO:tensorflow:Step 500 per-step time 1.763s
# I0518 16:59:59.652111 140640281061184 model_lib_v2.py:705] Step 500 per-step time 1.763s
# INFO:tensorflow:{'Loss/classification_loss': 0.1110577,
#  'Loss/localization_loss': 0.017763235,
#  'Loss/regularization_loss': 0.40053394,
#  'Loss/total_loss': 0.5293549,
#  'learning_rate': 0.01999975}
# I0518 16:59:59.652554 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.1110577,
#  'Loss/localization_loss': 0.017763235,
#  'Loss/regularization_loss': 0.40053394,
#  'Loss/total_loss': 0.5293549,
#  'learning_rate': 0.01999975}
# INFO:tensorflow:Step 600 per-step time 1.767s
# I0518 17:02:56.390111 140640281061184 model_lib_v2.py:705] Step 600 per-step time 1.767s
# INFO:tensorflow:{'Loss/classification_loss': 0.084355064,
#  'Loss/localization_loss': 0.019297574,
#  'Loss/regularization_loss': 0.39452586,
#  'Loss/total_loss': 0.49817848,
#  'learning_rate': 0.0213331}
# I0518 17:02:56.390576 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.084355064,
#  'Loss/localization_loss': 0.019297574,
#  'Loss/regularization_loss': 0.39452586,
#  'Loss/total_loss': 0.49817848,
#  'learning_rate': 0.0213331}
# INFO:tensorflow:Step 700 per-step time 1.757s
# I0518 17:05:52.062856 140640281061184 model_lib_v2.py:705] Step 700 per-step time 1.757s
# INFO:tensorflow:{'Loss/classification_loss': 0.075715534,
#  'Loss/localization_loss': 0.009101906,
#  'Loss/regularization_loss': 0.38821846,
#  'Loss/total_loss': 0.4730359,
#  'learning_rate': 0.02266645}
# I0518 17:05:52.063506 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.075715534,
#  'Loss/localization_loss': 0.009101906,
#  'Loss/regularization_loss': 0.38821846,
#  'Loss/total_loss': 0.4730359,
#  'learning_rate': 0.02266645}
# INFO:tensorflow:Step 800 per-step time 1.745s
# I0518 17:08:46.513812 140640281061184 model_lib_v2.py:705] Step 800 per-step time 1.745s
# INFO:tensorflow:{'Loss/classification_loss': 0.110058665,
#  'Loss/localization_loss': 0.01886973,
#  'Loss/regularization_loss': 0.38165575,
#  'Loss/total_loss': 0.5105841,
#  'learning_rate': 0.023999799}
# I0518 17:08:46.514291 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.110058665,
#  'Loss/localization_loss': 0.01886973,
#  'Loss/regularization_loss': 0.38165575,
#  'Loss/total_loss': 0.5105841,
#  'learning_rate': 0.023999799}
# INFO:tensorflow:Step 900 per-step time 1.741s
# I0518 17:11:40.656215 140640281061184 model_lib_v2.py:705] Step 900 per-step time 1.741s
# INFO:tensorflow:{'Loss/classification_loss': 0.0755688,
#  'Loss/localization_loss': 0.0113484515,
#  'Loss/regularization_loss': 0.37495425,
#  'Loss/total_loss': 0.4618715,
#  'learning_rate': 0.025333151}
# I0518 17:11:40.656625 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.0755688,
#  'Loss/localization_loss': 0.0113484515,
#  'Loss/regularization_loss': 0.37495425,
#  'Loss/total_loss': 0.4618715,
#  'learning_rate': 0.025333151}
# INFO:tensorflow:Step 1000 per-step time 1.739s
# I0518 17:14:34.509496 140640281061184 model_lib_v2.py:705] Step 1000 per-step time 1.739s
# INFO:tensorflow:{'Loss/classification_loss': 0.08224651,
#  'Loss/localization_loss': 0.010923458,
#  'Loss/regularization_loss': 0.36788824,
#  'Loss/total_loss': 0.4610582,
#  'learning_rate': 0.0266665}
# I0518 17:14:34.509852 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.08224651,
#  'Loss/localization_loss': 0.010923458,
#  'Loss/regularization_loss': 0.36788824,
#  'Loss/total_loss': 0.4610582,
#  'learning_rate': 0.0266665}
# INFO:tensorflow:Step 1100 per-step time 1.780s
# I0518 17:17:32.546909 140640281061184 model_lib_v2.py:705] Step 1100 per-step time 1.780s
# INFO:tensorflow:{'Loss/classification_loss': 0.06927621,
#  'Loss/localization_loss': 0.013799841,
#  'Loss/regularization_loss': 0.36070862,
#  'Loss/total_loss': 0.44378468,
#  'learning_rate': 0.02799985}
# I0518 17:17:32.547333 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.06927621,
#  'Loss/localization_loss': 0.013799841,
#  'Loss/regularization_loss': 0.36070862,
#  'Loss/total_loss': 0.44378468,
#  'learning_rate': 0.02799985}
# INFO:tensorflow:Step 1200 per-step time 1.739s
# I0518 17:20:26.416398 140640281061184 model_lib_v2.py:705] Step 1200 per-step time 1.739s
# INFO:tensorflow:{'Loss/classification_loss': 0.06334831,
#  'Loss/localization_loss': 0.016346298,
#  'Loss/regularization_loss': 0.35320675,
#  'Loss/total_loss': 0.43290135,
#  'learning_rate': 0.0293332}
# I0518 17:20:26.416844 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.06334831,
#  'Loss/localization_loss': 0.016346298,
#  'Loss/regularization_loss': 0.35320675,
#  'Loss/total_loss': 0.43290135,
#  'learning_rate': 0.0293332}
# INFO:tensorflow:Step 1300 per-step time 1.742s
# I0518 17:23:20.606869 140640281061184 model_lib_v2.py:705] Step 1300 per-step time 1.742s
# INFO:tensorflow:{'Loss/classification_loss': 0.0644025,
#  'Loss/localization_loss': 0.012880293,
#  'Loss/regularization_loss': 0.34556705,
#  'Loss/total_loss': 0.42284983,
#  'learning_rate': 0.03066655}
# I0518 17:23:20.607228 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.0644025,
#  'Loss/localization_loss': 0.012880293,
#  'Loss/regularization_loss': 0.34556705,
#  'Loss/total_loss': 0.42284983,
#  'learning_rate': 0.03066655}
# INFO:tensorflow:Step 1400 per-step time 1.742s
# I0518 17:26:14.817527 140640281061184 model_lib_v2.py:705] Step 1400 per-step time 1.742s
# INFO:tensorflow:{'Loss/classification_loss': 0.0621099,
#  'Loss/localization_loss': 0.010033158,
#  'Loss/regularization_loss': 0.33774203,
#  'Loss/total_loss': 0.40988508,
#  'learning_rate': 0.0319999}
# I0518 17:26:14.817885 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.0621099,
#  'Loss/localization_loss': 0.010033158,
#  'Loss/regularization_loss': 0.33774203,
#  'Loss/total_loss': 0.40988508,
#  'learning_rate': 0.0319999}
# INFO:tensorflow:Step 1500 per-step time 1.739s
# I0518 17:29:08.736704 140640281061184 model_lib_v2.py:705] Step 1500 per-step time 1.739s
# INFO:tensorflow:{'Loss/classification_loss': 0.05674328,
#  'Loss/localization_loss': 0.011354815,
#  'Loss/regularization_loss': 0.32984632,
#  'Loss/total_loss': 0.39794442,
#  'learning_rate': 0.03333325}
# I0518 17:29:08.737050 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.05674328,
#  'Loss/localization_loss': 0.011354815,
#  'Loss/regularization_loss': 0.32984632,
#  'Loss/total_loss': 0.39794442,
#  'learning_rate': 0.03333325}
# INFO:tensorflow:Step 1600 per-step time 1.746s
# I0518 17:32:03.295705 140640281061184 model_lib_v2.py:705] Step 1600 per-step time 1.746s
# INFO:tensorflow:{'Loss/classification_loss': 0.06649526,
#  'Loss/localization_loss': 0.008443644,
#  'Loss/regularization_loss': 0.3217092,
#  'Loss/total_loss': 0.3966481,
#  'learning_rate': 0.034666598}
# I0518 17:32:03.296117 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.06649526,
#  'Loss/localization_loss': 0.008443644,
#  'Loss/regularization_loss': 0.3217092,
#  'Loss/total_loss': 0.3966481,
#  'learning_rate': 0.034666598}
# INFO:tensorflow:Step 1700 per-step time 1.745s
# I0518 17:34:57.834142 140640281061184 model_lib_v2.py:705] Step 1700 per-step time 1.745s
# INFO:tensorflow:{'Loss/classification_loss': 0.073128,
#  'Loss/localization_loss': 0.013997104,
#  'Loss/regularization_loss': 0.31357276,
#  'Loss/total_loss': 0.4006979,
#  'learning_rate': 0.03599995}
# I0518 17:34:57.834620 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.073128,
#  'Loss/localization_loss': 0.013997104,
#  'Loss/regularization_loss': 0.31357276,
#  'Loss/total_loss': 0.4006979,
#  'learning_rate': 0.03599995}
# INFO:tensorflow:Step 1800 per-step time 1.742s
# I0518 17:37:52.024911 140640281061184 model_lib_v2.py:705] Step 1800 per-step time 1.742s
# INFO:tensorflow:{'Loss/classification_loss': 0.050604317,
#  'Loss/localization_loss': 0.009855614,
#  'Loss/regularization_loss': 0.30531535,
#  'Loss/total_loss': 0.3657753,
#  'learning_rate': 0.037333302}
# I0518 17:37:52.025374 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.050604317,
#  'Loss/localization_loss': 0.009855614,
#  'Loss/regularization_loss': 0.30531535,
#  'Loss/total_loss': 0.3657753,
#  'learning_rate': 0.037333302}
# INFO:tensorflow:Step 1900 per-step time 1.741s
# I0518 17:40:46.140790 140640281061184 model_lib_v2.py:705] Step 1900 per-step time 1.741s
# INFO:tensorflow:{'Loss/classification_loss': 0.056877088,
#  'Loss/localization_loss': 0.009489338,
#  'Loss/regularization_loss': 0.2971215,
#  'Loss/total_loss': 0.36348793,
#  'learning_rate': 0.03866665}
# I0518 17:40:46.141265 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.056877088,
#  'Loss/localization_loss': 0.009489338,
#  'Loss/regularization_loss': 0.2971215,
#  'Loss/total_loss': 0.36348793,
#  'learning_rate': 0.03866665}
# INFO:tensorflow:Step 2000 per-step time 1.744s
# I0518 17:43:40.523833 140640281061184 model_lib_v2.py:705] Step 2000 per-step time 1.744s
# INFO:tensorflow:{'Loss/classification_loss': 0.07815104,
#  'Loss/localization_loss': 0.0081374785,
#  'Loss/regularization_loss': 0.28881997,
#  'Loss/total_loss': 0.37510848,
#  'learning_rate': nan}
# I0518 17:43:40.524177 140640281061184 model_lib_v2.py:708] {'Loss/classification_loss': 0.07815104,
#  'Loss/localization_loss': 0.0081374785,
#  'Loss/regularization_loss': 0.28881997,
#  'Loss/total_loss': 0.37510848,
#  'learning_rate': nan}

# %%
pwd
# Out:
# '/content/training_demo'

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path /content/training_demo/models/my_ssd_resnet101_v1_fpn/pipeline.config --trained_checkpoint_dir /content/training_demo/models/my_ssd_resnet101_v1_fpn --output_directory /content/training_demo/exported_models/my_model
# Out:
# 2023-05-18 17:49:56.648249: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2023-05-18 17:50:05.493857: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0518 17:50:06.039126 140061529941824 deprecation.py:641] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0518 17:50:15.252290 140061529941824 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0518 17:50:27.172966 140061529941824 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0518 17:50:33.557204 140061529941824 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f622bc3ad70>, because it is not built.
# W0518 17:50:35.813330 140061529941824 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f622bc3ad70>, because it is not built.
# W0518 17:51:16.082221 140061529941824 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 329). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/training_demo/exported_models/my_model/saved_model/assets
# I0518 17:51:33.545411 140061529941824 builder_impl.py:797] Assets written to: /content/training_demo/exported_models/my_model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to /content/training_demo/exported_models/my_model/pipeline.config
# I0518 17:51:35.909206 140061529941824 config_util.py:253] Writing pipeline config file to /content/training_demo/exported_models/my_model/pipeline.config

# %% [markdown]
# Inferencing My Trained Models

# %%
"""
Object Detection (On Image) From TF2 Saved Model
=====================================
"""

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
import pathlib
import tensorflow as tf
import cv2
import argparse
from google.colab.patches import cv2_imshow

# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# PROVIDE PATH TO IMAGE DIRECTORY
IMAGE_PATHS = '/content/training_demo/images/train/image1.jpg'


# PROVIDE PATH TO MODEL DIRECTORY
PATH_TO_MODEL_DIR = '/content/training_demo/exported_models/my_model'

# PROVIDE PATH TO LABEL MAP
PATH_TO_LABELS = '/content/training_demo/annotations/label_map.pbtxt'

# PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
MIN_CONF_THRESH = float(0.60)

# LOAD THE MODEL

import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

print('Loading model...', end='')
start_time = time.time()

# LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))

# LOAD LABEL MAP DATA FOR PLOTTING

category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,
                                                                    use_display_name=True)

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.
    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.
    Args:
      path: the file path to the image
    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))




print('Running inference for {}... '.format(IMAGE_PATHS), end='')

image = cv2.imread(IMAGE_PATHS)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_expanded = np.expand_dims(image_rgb, axis=0)

# The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
input_tensor = tf.convert_to_tensor(image)
# The model expects a batch of images, so add an axis with `tf.newaxis`.
input_tensor = input_tensor[tf.newaxis, ...]

# input_tensor = np.expand_dims(image_np, 0)
detections = detect_fn(input_tensor)

# All outputs are batches tensors.
# Convert to numpy arrays, and take index [0] to remove the batch dimension.
# We're only interested in the first num_detections.
num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
               for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

image_with_detections = image.copy()

# SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
viz_utils.visualize_boxes_and_labels_on_image_array(
      image_with_detections,
      detections['detection_boxes'],
      detections['detection_classes'],
      detections['detection_scores'],
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=200,
      min_score_thresh=0.5,
      agnostic_mode=False)

print('Done')
# DISPLAYS OUTPUT IMAGE
cv2_imshow(image_with_detections)
# CLOSES WINDOW ONCE KEY IS PRESSED
# Out:
# Loading model...Done! Took 20.542906761169434 seconds
# Running inference for /content/training_demo/images/train/image1.jpg... Done
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F663022E920>

# %%
# !zip -r /content/TensorFlowObjectDetection.zip /content
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 24%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2023.05.16/ (stored 0%)
#   adding: content/.config/logs/2023.05.16/19.32.37.114495.log (deflated 58%)
#   adding: content/.config/logs/2023.05.16/19.32.02.474728.log (deflated 58%)
#   adding: content/.config/logs/2023.05.16/19.33.04.586387.log (deflated 57%)
#   adding: content/.config/logs/2023.05.16/19.33.05.389801.log (deflated 56%)
#   adding: content/.config/logs/2023.05.16/19.31.37.487297.log (deflated 91%)
#   adding: content/.config/logs/2023.05.16/19.32.29.223621.log (deflated 86%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.ipynb_checkpoints/ (stored 0%)
#   adding: content/models/ (stored 0%)
#   adding: content/models/orbit/ (stored 0%)
#   adding: content/models/orbit/utils/ (stored 0%)
#   adding: content/models/orbit/utils/common.py (deflated 58%)
#   adding: content/models/orbit/utils/summary_manager.py (deflated 63%)
#   adding: content/models/orbit/utils/tpu_summaries_test.py (deflated 70%)
#   adding: content/models/orbit/utils/summary_manager_interface.py (deflated 56%)
#   adding: content/models/orbit/utils/tpu_summaries.py (deflated 63%)
#   adding: content/models/orbit/utils/common_test.py (deflated 44%)
#   adding: content/models/orbit/utils/epoch_helper.py (deflated 59%)
#   adding: content/models/orbit/utils/__init__.py (deflated 52%)
#   adding: content/models/orbit/utils/loop_fns.py (deflated 70%)
#   adding: content/models/orbit/controller_test.py (deflated 86%)
#   adding: content/models/orbit/examples/ (stored 0%)
#   adding: content/models/orbit/examples/single_task/ (stored 0%)
#   adding: content/models/orbit/examples/single_task/single_task_evaluator_test.py (deflated 55%)
#   adding: content/models/orbit/examples/single_task/single_task_evaluator.py (deflated 57%)
#   adding: content/models/orbit/examples/single_task/single_task_trainer_test.py (deflated 52%)
#   adding: content/models/orbit/examples/single_task/__init__.py (deflated 37%)
#   adding: content/models/orbit/examples/single_task/single_task_trainer.py (deflated 61%)
#   adding: content/models/orbit/examples/__init__.py (deflated 37%)
#   adding: content/models/orbit/README.md (deflated 40%)
#   adding: content/models/orbit/standard_runner_test.py (deflated 72%)
#   adding: content/models/orbit/actions/ (stored 0%)
#   adding: content/models/orbit/actions/conditional_action_test.py (deflated 47%)
#   adding: content/models/orbit/actions/save_checkpoint_if_preempted.py (deflated 59%)
#   adding: content/models/orbit/actions/new_best_metric_test.py (deflated 72%)
#   adding: content/models/orbit/actions/conditional_action.py (deflated 52%)
#   adding: content/models/orbit/actions/new_best_metric.py (deflated 66%)
#   adding: content/models/orbit/actions/export_saved_model.py (deflated 61%)
#   adding: content/models/orbit/actions/__init__.py (deflated 55%)
#   adding: content/models/orbit/actions/export_saved_model_test.py (deflated 82%)
#   adding: content/models/orbit/LICENSE (deflated 65%)
#   adding: content/models/orbit/__init__.py (deflated 54%)
#   adding: content/models/orbit/standard_runner.py (deflated 74%)
#   adding: content/models/orbit/controller.py (deflated 72%)
#   adding: content/models/orbit/runner.py (deflated 60%)
#   adding: content/models/CODEOWNERS (deflated 55%)
#   adding: content/models/SECURITY.md (deflated 53%)
#   adding: content/models/README.md (deflated 58%)
#   adding: content/models/research/ (stored 0%)
#   adding: content/models/research/slim/ (stored 0%)
#   adding: content/models/research/slim/nets/ (stored 0%)
#   adding: content/models/research/slim/nets/dcgan_test.py (deflated 67%)
#   adding: content/models/research/slim/nets/cyclegan.py (deflated 68%)
#   adding: content/models/research/slim/nets/resnet_v2_test.py (deflated 81%)
#   adding: content/models/research/slim/nets/alexnet.py (deflated 63%)
#   adding: content/models/research/slim/nets/inception_v2.py (deflated 83%)
#   adding: content/models/research/slim/nets/inception.py (deflated 65%)
#   adding: content/models/research/slim/nets/resnet_utils.py (deflated 65%)
#   adding: content/models/research/slim/nets/inception_v1_test.py (deflated 80%)
#   adding: content/models/research/slim/nets/inception_v4_test.py (deflated 82%)
#   adding: content/models/research/slim/nets/cyclegan_test.py (deflated 71%)
#   adding: content/models/research/slim/nets/inception_v3_test.py (deflated 82%)
#   adding: content/models/research/slim/nets/nets_factory_test.py (deflated 72%)
#   adding: content/models/research/slim/nets/inception_v3.py (deflated 84%)
#   adding: content/models/research/slim/nets/resnet_v2.py (deflated 73%)
#   adding: content/models/research/slim/nets/i3d_test.py (deflated 74%)
#   adding: content/models/research/slim/nets/lenet.py (deflated 58%)
#   adding: content/models/research/slim/nets/mobilenet/ (stored 0%)
#   adding: content/models/research/slim/nets/mobilenet/mobilenet.py (deflated 66%)
#   adding: content/models/research/slim/nets/mobilenet/mobilenet_v3.py (deflated 88%)
#   adding: content/models/research/slim/nets/mobilenet/mobilenet_v2.py (deflated 68%)
#   adding: content/models/research/slim/nets/mobilenet/README.md (deflated 76%)
#   adding: content/models/research/slim/nets/mobilenet/mobilenet_example.ipynb (deflated 28%)
#   adding: content/models/research/slim/nets/mobilenet/conv_blocks.py (deflated 71%)
#   adding: content/models/research/slim/nets/mobilenet/mobilenet_v2_test.py (deflated 72%)
#   adding: content/models/research/slim/nets/mobilenet/__init__.py (stored 0%)
#   adding: content/models/research/slim/nets/mobilenet/g3doc/ (stored 0%)
#   adding: content/models/research/slim/nets/mobilenet/g3doc/madds_top1_accuracy.png (deflated 2%)
#   adding: content/models/research/slim/nets/mobilenet/g3doc/edgetpu_latency.png (deflated 8%)
#   adding: content/models/research/slim/nets/mobilenet/g3doc/latency_pixel1.png (deflated 1%)
#   adding: content/models/research/slim/nets/mobilenet/mnet_v1_vs_v2_pixel1_latency.png (deflated 10%)
#   adding: content/models/research/slim/nets/mobilenet/mobilenet_v3_test.py (deflated 76%)
#   adding: content/models/research/slim/nets/inception_v1.py (deflated 83%)
#   adding: content/models/research/slim/nets/mobilenet_v1.py (deflated 74%)
#   adding: content/models/research/slim/nets/alexnet_test.py (deflated 80%)
#   adding: content/models/research/slim/nets/s3dg.py (deflated 80%)
#   adding: content/models/research/slim/nets/i3d.py (deflated 62%)
#   adding: content/models/research/slim/nets/inception_v4.py (deflated 81%)
#   adding: content/models/research/slim/nets/mobilenet_v1_train.py (deflated 65%)
#   adding: content/models/research/slim/nets/resnet_v1.py (deflated 74%)
#   adding: content/models/research/slim/nets/mobilenet_v1_test.py (deflated 88%)
#   adding: content/models/research/slim/nets/resnet_v1_test.py (deflated 83%)
#   adding: content/models/research/slim/nets/overfeat.py (deflated 65%)
#   adding: content/models/research/slim/nets/inception_resnet_v2_test.py (deflated 84%)
#   adding: content/models/research/slim/nets/post_training_quantization.py (deflated 63%)
#   adding: content/models/research/slim/nets/inception_v2_test.py (deflated 82%)
#   adding: content/models/research/slim/nets/i3d_utils.py (deflated 72%)
#   adding: content/models/research/slim/nets/nasnet/ (stored 0%)
#   adding: content/models/research/slim/nets/nasnet/README.md (deflated 61%)
#   adding: content/models/research/slim/nets/nasnet/nasnet_test.py (deflated 87%)
#   adding: content/models/research/slim/nets/nasnet/pnasnet_test.py (deflated 83%)
#   adding: content/models/research/slim/nets/nasnet/nasnet.py (deflated 81%)
#   adding: content/models/research/slim/nets/nasnet/nasnet_utils_test.py (deflated 61%)
#   adding: content/models/research/slim/nets/nasnet/__init__.py (stored 0%)
#   adding: content/models/research/slim/nets/nasnet/nasnet_utils.py (deflated 74%)
#   adding: content/models/research/slim/nets/nasnet/pnasnet.py (deflated 75%)
#   adding: content/models/research/slim/nets/inception_resnet_v2.py (deflated 77%)
#   adding: content/models/research/slim/nets/__init__.py (stored 0%)
#   adding: content/models/research/slim/nets/pix2pix.py (deflated 66%)
#   adding: content/models/research/slim/nets/pix2pix_test.py (deflated 76%)
#   adding: content/models/research/slim/nets/nets_factory.py (deflated 72%)
#   adding: content/models/research/slim/nets/inception_utils.py (deflated 59%)
#   adding: content/models/research/slim/nets/vgg.py (deflated 82%)
#   adding: content/models/research/slim/nets/mobilenet_v1_eval.py (deflated 62%)
#   adding: content/models/research/slim/nets/overfeat_test.py (deflated 80%)
#   adding: content/models/research/slim/nets/cifarnet.py (deflated 61%)
#   adding: content/models/research/slim/nets/vgg_test.py (deflated 91%)
#   adding: content/models/research/slim/nets/mobilenet_v1.png (deflated 2%)
#   adding: content/models/research/slim/nets/dcgan.py (deflated 70%)
#   adding: content/models/research/slim/nets/s3dg_test.py (deflated 74%)
#   adding: content/models/research/slim/nets/mobilenet_v1.md (deflated 74%)
#   adding: content/models/research/slim/README.md (deflated 70%)
#   adding: content/models/research/slim/train_image_classifier.py (deflated 73%)
#   adding: content/models/research/slim/WORKSPACE (stored 0%)
#   adding: content/models/research/slim/export_inference_graph_test.py (deflated 49%)
#   adding: content/models/research/slim/setup.py (deflated 47%)
#   adding: content/models/research/slim/datasets/ (stored 0%)
#   adding: content/models/research/slim/datasets/download_and_convert_cifar10.py (deflated 63%)
#   adding: content/models/research/slim/datasets/download_and_convert_imagenet.sh (deflated 60%)
#   adding: content/models/research/slim/datasets/download_and_convert_mnist.py (deflated 67%)
#   adding: content/models/research/slim/datasets/cifar10.py (deflated 56%)
#   adding: content/models/research/slim/datasets/download_and_convert_flowers.py (deflated 64%)
#   adding: content/models/research/slim/datasets/mnist.py (deflated 56%)
#   adding: content/models/research/slim/datasets/visualwakewords.py (deflated 60%)
#   adding: content/models/research/slim/datasets/download_and_convert_visualwakewords.py (deflated 67%)
#   adding: content/models/research/slim/datasets/imagenet.py (deflated 61%)
#   adding: content/models/research/slim/datasets/flowers.py (deflated 56%)
#   adding: content/models/research/slim/datasets/imagenet_metadata.txt (deflated 60%)
#   adding: content/models/research/slim/datasets/dataset_factory.py (deflated 54%)
#   adding: content/models/research/slim/datasets/download_imagenet.sh (deflated 59%)
#   adding: content/models/research/slim/datasets/imagenet_lsvrc_2015_synsets.txt (deflated 62%)
#   adding: content/models/research/slim/datasets/__init__.py (stored 0%)
#   adding: content/models/research/slim/datasets/preprocess_imagenet_validation_data.py (deflated 56%)
#   adding: content/models/research/slim/datasets/imagenet_2012_validation_synset_labels.txt (deflated 76%)
#   adding: content/models/research/slim/datasets/download_and_convert_visualwakewords_lib.py (deflated 72%)
#   adding: content/models/research/slim/datasets/dataset_utils.py (deflated 68%)
#   adding: content/models/research/slim/datasets/process_bounding_boxes.py (deflated 63%)
#   adding: content/models/research/slim/datasets/build_imagenet_data.py (deflated 73%)
#   adding: content/models/research/slim/__init__.py (stored 0%)
#   adding: content/models/research/slim/preprocessing/ (stored 0%)
#   adding: content/models/research/slim/preprocessing/cifarnet_preprocessing.py (deflated 73%)
#   adding: content/models/research/slim/preprocessing/lenet_preprocessing.py (deflated 55%)
#   adding: content/models/research/slim/preprocessing/__init__.py (stored 0%)
#   adding: content/models/research/slim/preprocessing/preprocessing_factory.py (deflated 70%)
#   adding: content/models/research/slim/preprocessing/vgg_preprocessing.py (deflated 73%)
#   adding: content/models/research/slim/preprocessing/inception_preprocessing.py (deflated 74%)
#   adding: content/models/research/slim/BUILD (deflated 91%)
#   adding: content/models/research/slim/deployment/ (stored 0%)
#   adding: content/models/research/slim/deployment/model_deploy_test.py (deflated 88%)
#   adding: content/models/research/slim/deployment/__init__.py (stored 0%)
#   adding: content/models/research/slim/deployment/model_deploy.py (deflated 74%)
#   adding: content/models/research/slim/download_and_convert_data.py (deflated 64%)
#   adding: content/models/research/slim/eval_image_classifier.py (deflated 66%)
#   adding: content/models/research/slim/slim_walkthrough.ipynb (deflated 78%)
#   adding: content/models/research/slim/export_inference_graph.py (deflated 63%)
#   adding: content/models/research/slim/scripts/ (stored 0%)
#   adding: content/models/research/slim/scripts/finetune_resnet_v1_50_on_flowers.sh (deflated 67%)
#   adding: content/models/research/slim/scripts/train_cifarnet_on_cifar10.sh (deflated 55%)
#   adding: content/models/research/slim/scripts/finetune_inception_resnet_v2_on_flowers.sh (deflated 68%)
#   adding: content/models/research/slim/scripts/export_mobilenet.sh (deflated 63%)
#   adding: content/models/research/slim/scripts/finetune_inception_v1_on_flowers.sh (deflated 67%)
#   adding: content/models/research/slim/scripts/finetune_inception_v3_on_flowers.sh (deflated 67%)
#   adding: content/models/research/slim/scripts/train_lenet_on_mnist.sh (deflated 54%)
#   adding: content/models/research/object_detection.egg-info/ (stored 0%)
#   adding: content/models/research/object_detection.egg-info/SOURCES.txt (deflated 89%)
#   adding: content/models/research/object_detection.egg-info/top_level.txt (deflated 7%)
#   adding: content/models/research/object_detection.egg-info/dependency_links.txt (stored 0%)
#   adding: content/models/research/object_detection.egg-info/PKG-INFO (deflated 17%)
#   adding: content/models/research/object_detection.egg-info/requires.txt (deflated 23%)
#   adding: content/models/research/rebar/ (stored 0%)
#   adding: content/models/research/rebar/download_data.py (deflated 60%)
#   adding: content/models/research/rebar/config.py (deflated 45%)
#   adding: content/models/research/rebar/datasets.py (deflated 60%)
#   adding: content/models/research/rebar/README.md (deflated 57%)
#   adding: content/models/research/rebar/rebar_train.py (deflated 65%)
#   adding: content/models/research/rebar/rebar.py (deflated 81%)
#   adding: content/models/research/rebar/logger.py (deflated 47%)
#   adding: content/models/research/rebar/utils.py (deflated 57%)
#   adding: content/models/research/cognitive_planning/ (stored 0%)
#   adding: content/models/research/cognitive_planning/policies.py (deflated 72%)
#   adding: content/models/research/cognitive_planning/standard_fields.py (deflated 74%)
#   adding: content/models/research/cognitive_planning/label_map.txt (deflated 78%)
#   adding: content/models/research/cognitive_planning/README.md (deflated 63%)
#   adding: content/models/research/cognitive_planning/train_supervised_active_vision.sh (deflated 48%)
#   adding: content/models/research/cognitive_planning/visualization_utils.py (deflated 76%)
#   adding: content/models/research/cognitive_planning/command (deflated 46%)
#   adding: content/models/research/cognitive_planning/tasks.py (deflated 77%)
#   adding: content/models/research/cognitive_planning/string_int_label_map_pb2.py (deflated 73%)
#   adding: content/models/research/cognitive_planning/__init__.py (stored 0%)
#   adding: content/models/research/cognitive_planning/preprocessing/ (stored 0%)
#   adding: content/models/research/cognitive_planning/preprocessing/cifarnet_preprocessing.py (deflated 71%)
#   adding: content/models/research/cognitive_planning/preprocessing/lenet_preprocessing.py (deflated 52%)
#   adding: content/models/research/cognitive_planning/preprocessing/__init__.py (stored 0%)
#   adding: content/models/research/cognitive_planning/preprocessing/preprocessing_factory.py (deflated 67%)
#   adding: content/models/research/cognitive_planning/preprocessing/vgg_preprocessing.py (deflated 73%)
#   adding: content/models/research/cognitive_planning/preprocessing/inception_preprocessing.py (deflated 73%)
#   adding: content/models/research/cognitive_planning/BUILD (deflated 40%)
#   adding: content/models/research/cognitive_planning/viz_active_vision_dataset_main.py (deflated 69%)
#   adding: content/models/research/cognitive_planning/train_supervised_active_vision.py (deflated 69%)
#   adding: content/models/research/cognitive_planning/embedders.py (deflated 74%)
#   adding: content/models/research/cognitive_planning/label_map_util.py (deflated 66%)
#   adding: content/models/research/cognitive_planning/envs/ (stored 0%)
#   adding: content/models/research/cognitive_planning/envs/task_env.py (deflated 66%)
#   adding: content/models/research/cognitive_planning/envs/configs/ (stored 0%)
#   adding: content/models/research/cognitive_planning/envs/configs/active_vision_config.gin (deflated 64%)
#   adding: content/models/research/cognitive_planning/envs/active_vision_dataset_env.py (deflated 74%)
#   adding: content/models/research/cognitive_planning/envs/__init__.py (stored 0%)
#   adding: content/models/research/cognitive_planning/envs/util.py (deflated 53%)
#   adding: content/models/research/README.md (deflated 63%)
#   adding: content/models/research/deeplab/ (stored 0%)
#   adding: content/models/research/deeplab/common.py (deflated 69%)
#   adding: content/models/research/deeplab/vis.py (deflated 68%)
#   adding: content/models/research/deeplab/local_test_mobilenetv2.sh (deflated 61%)
#   adding: content/models/research/deeplab/utils/ (stored 0%)
#   adding: content/models/research/deeplab/utils/train_utils.py (deflated 71%)
#   adding: content/models/research/deeplab/utils/save_annotation.py (deflated 58%)
#   adding: content/models/research/deeplab/utils/get_dataset_colormap_test.py (deflated 69%)
#   adding: content/models/research/deeplab/utils/__init__.py (stored 0%)
#   adding: content/models/research/deeplab/utils/get_dataset_colormap.py (deflated 72%)
#   adding: content/models/research/deeplab/local_test.sh (deflated 64%)
#   adding: content/models/research/deeplab/export_model.py (deflated 65%)
#   adding: content/models/research/deeplab/README.md (deflated 62%)
#   adding: content/models/research/deeplab/core/ (stored 0%)
#   adding: content/models/research/deeplab/core/dense_prediction_cell_branch5_top1_cityscapes.json (deflated 71%)
#   adding: content/models/research/deeplab/core/nas_genotypes.py (deflated 54%)
#   adding: content/models/research/deeplab/core/preprocess_utils.py (deflated 71%)
#   adding: content/models/research/deeplab/core/xception_test.py (deflated 84%)
#   adding: content/models/research/deeplab/core/nas_network_test.py (deflated 62%)
#   adding: content/models/research/deeplab/core/conv2d_ws_test.py (deflated 86%)
#   adding: content/models/research/deeplab/core/nas_cell.py (deflated 70%)
#   adding: content/models/research/deeplab/core/dense_prediction_cell.py (deflated 72%)
#   adding: content/models/research/deeplab/core/xception.py (deflated 81%)
#   adding: content/models/research/deeplab/core/nas_network.py (deflated 73%)
#   adding: content/models/research/deeplab/core/utils_test.py (deflated 69%)
#   adding: content/models/research/deeplab/core/resnet_v1_beta_test.py (deflated 88%)
#   adding: content/models/research/deeplab/core/__init__.py (stored 0%)
#   adding: content/models/research/deeplab/core/preprocess_utils_test.py (deflated 85%)
#   adding: content/models/research/deeplab/core/conv2d_ws.py (deflated 70%)
#   adding: content/models/research/deeplab/core/utils.py (deflated 67%)
#   adding: content/models/research/deeplab/core/resnet_v1_beta.py (deflated 85%)
#   adding: content/models/research/deeplab/core/feature_extractor.py (deflated 79%)
#   adding: content/models/research/deeplab/core/dense_prediction_cell_test.py (deflated 75%)
#   adding: content/models/research/deeplab/common_test.py (deflated 64%)
#   adding: content/models/research/deeplab/model.py (deflated 78%)
#   adding: content/models/research/deeplab/deeplab_demo.ipynb (deflated 70%)
#   adding: content/models/research/deeplab/input_preprocess.py (deflated 68%)
#   adding: content/models/research/deeplab/datasets/ (stored 0%)
#   adding: content/models/research/deeplab/datasets/build_cityscapes_data.py (deflated 62%)
#   adding: content/models/research/deeplab/datasets/build_data.py (deflated 66%)
#   adding: content/models/research/deeplab/datasets/download_and_convert_ade20k.sh (deflated 56%)
#   adding: content/models/research/deeplab/datasets/build_voc2012_data.py (deflated 63%)
#   adding: content/models/research/deeplab/datasets/build_ade20k_data.py (deflated 62%)
#   adding: content/models/research/deeplab/datasets/convert_cityscapes.sh (deflated 52%)
#   adding: content/models/research/deeplab/datasets/__init__.py (stored 0%)
#   adding: content/models/research/deeplab/datasets/data_generator.py (deflated 67%)
#   adding: content/models/research/deeplab/datasets/download_and_convert_voc2012.sh (deflated 56%)
#   adding: content/models/research/deeplab/datasets/remove_gt_colormap.py (deflated 61%)
#   adding: content/models/research/deeplab/datasets/data_generator_test.py (deflated 59%)
#   adding: content/models/research/deeplab/__init__.py (stored 0%)
#   adding: content/models/research/deeplab/g3doc/ (stored 0%)
#   adding: content/models/research/deeplab/g3doc/img/ (stored 0%)
#   adding: content/models/research/deeplab/g3doc/img/vis2.png (deflated 1%)
#   adding: content/models/research/deeplab/g3doc/img/image2.jpg (deflated 0%)
#   adding: content/models/research/deeplab/g3doc/img/image1.jpg (deflated 0%)
#   adding: content/models/research/deeplab/g3doc/img/vis1.png (deflated 1%)
#   adding: content/models/research/deeplab/g3doc/img/vis3.png (deflated 0%)
#   adding: content/models/research/deeplab/g3doc/img/image_info.txt (deflated 37%)
#   adding: content/models/research/deeplab/g3doc/img/image3.jpg (deflated 0%)
#   adding: content/models/research/deeplab/g3doc/faq.md (deflated 53%)
#   adding: content/models/research/deeplab/g3doc/quantize.md (deflated 63%)
#   adding: content/models/research/deeplab/g3doc/pascal.md (deflated 68%)
#   adding: content/models/research/deeplab/g3doc/cityscapes.md (deflated 67%)
#   adding: content/models/research/deeplab/g3doc/installation.md (deflated 56%)
#   adding: content/models/research/deeplab/g3doc/model_zoo.md (deflated 71%)
#   adding: content/models/research/deeplab/g3doc/ade20k.md (deflated 58%)
#   adding: content/models/research/deeplab/g3doc/export_model.md (deflated 48%)
#   adding: content/models/research/deeplab/testing/ (stored 0%)
#   adding: content/models/research/deeplab/testing/pascal_voc_seg/ (stored 0%)
#   adding: content/models/research/deeplab/testing/pascal_voc_seg/val-00000-of-00001.tfrecord (deflated 0%)
#   adding: content/models/research/deeplab/testing/info.md (deflated 35%)
#   adding: content/models/research/deeplab/train.py (deflated 70%)
#   adding: content/models/research/deeplab/convert_to_tflite.py (deflated 60%)
#   adding: content/models/research/deeplab/deprecated/ (stored 0%)
#   adding: content/models/research/deeplab/deprecated/__init__.py (stored 0%)
#   adding: content/models/research/deeplab/deprecated/segmentation_dataset.py (deflated 63%)
#   adding: content/models/research/deeplab/eval.py (deflated 67%)
#   adding: content/models/research/deeplab/model_test.py (deflated 69%)
#   adding: content/models/research/deeplab/evaluation/ (stored 0%)
#   adding: content/models/research/deeplab/evaluation/streaming_metrics.py (deflated 77%)
#   adding: content/models/research/deeplab/evaluation/eval_coco_format_test.py (deflated 78%)
#   adding: content/models/research/deeplab/evaluation/parsing_covering_test.py (deflated 73%)
#   adding: content/models/research/deeplab/evaluation/panoptic_quality_test.py (deflated 82%)
#   adding: content/models/research/deeplab/evaluation/eval_coco_format.py (deflated 70%)
#   adding: content/models/research/deeplab/evaluation/parsing_covering.py (deflated 68%)
#   adding: content/models/research/deeplab/evaluation/README.md (deflated 64%)
#   adding: content/models/research/deeplab/evaluation/panoptic_quality.py (deflated 70%)
#   adding: content/models/research/deeplab/evaluation/test_utils_test.py (deflated 62%)
#   adding: content/models/research/deeplab/evaluation/__init__.py (stored 0%)
#   adding: content/models/research/deeplab/evaluation/test_utils.py (deflated 62%)
#   adding: content/models/research/deeplab/evaluation/g3doc/ (stored 0%)
#   adding: content/models/research/deeplab/evaluation/g3doc/img/ (stored 0%)
#   adding: content/models/research/deeplab/evaluation/g3doc/img/equation_pq.png (deflated 5%)
#   adding: content/models/research/deeplab/evaluation/g3doc/img/equation_pc.png (deflated 8%)
#   adding: content/models/research/deeplab/evaluation/testdata/ (stored 0%)
#   adding: content/models/research/deeplab/evaluation/testdata/cat_pred_class.png (deflated 18%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_gt.json (deflated 82%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_pred.json (deflated 82%)
#   adding: content/models/research/deeplab/evaluation/testdata/team_pred_instance.png (deflated 2%)
#   adding: content/models/research/deeplab/evaluation/testdata/README.md (deflated 48%)
#   adding: content/models/research/deeplab/evaluation/testdata/cat_pred_instance.png (deflated 12%)
#   adding: content/models/research/deeplab/evaluation/testdata/team_gt_instance.png (deflated 1%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_pred/ (stored 0%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_pred/cat.png (deflated 2%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_pred/bird.png (deflated 0%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_pred/team.png (deflated 0%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_pred/congress.png (deflated 12%)
#   adding: content/models/research/deeplab/evaluation/testdata/bird_gt.png (stored 0%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_gt/ (stored 0%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_gt/cat.png (deflated 1%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_gt/bird.png (deflated 1%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_gt/team.png (stored 0%)
#   adding: content/models/research/deeplab/evaluation/testdata/coco_gt/congress.png (deflated 6%)
#   adding: content/models/research/deeplab/evaluation/testdata/bird_pred_class.png (deflated 1%)
#   adding: content/models/research/deeplab/evaluation/testdata/bird_pred_instance.png (deflated 1%)
#   adding: content/models/research/deeplab/evaluation/testdata/cat_gt.png (deflated 9%)
#   adding: content/models/research/deeplab/evaluation/testdata/team_pred_class.png (deflated 8%)
#   adding: content/models/research/deeplab/evaluation/base_metric.py (deflated 66%)
#   adding: content/models/research/deeplab/evaluation/streaming_metrics_test.py (deflated 86%)
#   adding: content/models/research/object_detection/ (stored 0%)
#   adding: content/models/research/object_detection/eval_util.py (deflated 78%)
#   adding: content/models/research/object_detection/data_decoders/ (stored 0%)
#   adding: content/models/research/object_detection/data_decoders/tf_example_decoder_test.py (deflated 93%)
#   adding: content/models/research/object_detection/data_decoders/tf_sequence_example_decoder.py (deflated 73%)
#   adding: content/models/research/object_detection/data_decoders/tf_example_decoder.py (deflated 80%)
#   adding: content/models/research/object_detection/data_decoders/tf_sequence_example_decoder_test.py (deflated 84%)
#   adding: content/models/research/object_detection/data_decoders/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/configs/ (stored 0%)
#   adding: content/models/research/object_detection/configs/tf1/ (stored 0%)
#   adding: content/models/research/object_detection/configs/tf1/ssd_spaghettinet_edgetpu_320x320_coco17_sync_4x4.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/ (stored 0%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_efficientdet_d5_1280x1280_coco17_tpu-32.config (deflated 66%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_mobilenet_v2_320x320_coco17_tpu-8.config (deflated 67%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet50_v1_800x1333_coco17_gpu-8.config (deflated 66%)
#   adding: content/models/research/object_detection/configs/tf2/centernet_resnet50_v2_512x512_kpts_coco17_tpu-8.config (deflated 78%)
#   adding: content/models/research/object_detection/configs/tf2/centernet_resnet101_v1_fpn_512x512_coco17_tpu-8.config (deflated 63%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_efficientdet_d0_512x512_coco17_tpu-8.config (deflated 66%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_resnet152_v1_fpn_640x640_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet50_v1_fpn_640x640_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet50_v1_1024x1024_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_resnet101_v1_fpn_1024x1024_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/centernet_resnet50_v1_fpn_512x512_kpts_coco17_tpu-8.config (deflated 78%)
#   adding: content/models/research/object_detection/configs/tf2/center_net_deepmac_1024x1024_coco_tpu-128.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_efficientdet_d1_640x640_coco17_tpu-8.config (deflated 66%)
#   adding: content/models/research/object_detection/configs/tf2/centernet_hourglass104_512x512_coco17_tpu-8.config (deflated 62%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet101_v1_640x640_coco17_tpu-8.config (deflated 64%)
#   adding: content/models/research/object_detection/configs/tf2/centernet_hourglass104_1024x1024_kpts_coco17_tpu-32.config (deflated 78%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet101_v1_800x1333_coco17_gpu-8.config (deflated 66%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet50_v1_640x640_coco17_tpu-8.config (deflated 64%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet152_v1_800x1333_coco17_gpu-8.config (deflated 66%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/center_net_deepmac_1024x1024_non_voc_only_tpu-128.config (deflated 68%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_efficientdet_d4_1024x1024_coco17_tpu-32.config (deflated 66%)
#   adding: content/models/research/object_detection/configs/tf2/centernet_hourglass104_1024x1024_coco17_tpu-32.config (deflated 61%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_mobilenet_v1_fpn_640x640_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/center_net_deepmac_1024x1024_voc_only_tpu-128.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/center_net_deepmac_512x512_voc_only_tpu-32.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_efficientdet_d6_1408x1408_coco17_tpu-32.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/mask_rcnn_inception_resnet_v2_1024x1024_coco17_gpu-8.config (deflated 67%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_resnet152_v1_fpn_1024x1024_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_resnet50_v1_fpn_1024x1024_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_efficientdet_d2_768x768_coco17_tpu-8.config (deflated 66%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet152_v1_1024x1024_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/centernet_hourglass104_512x512_kpts_coco17_tpu-32.config (deflated 78%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_efficientdet_d3_896x896_coco17_tpu-32.config (deflated 66%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet152_v1_640x640_coco17_tpu-8.config (deflated 64%)
#   adding: content/models/research/object_detection/configs/tf2/ssd_efficientdet_d7_1536x1536_coco17_tpu-32.config (deflated 65%)
#   adding: content/models/research/object_detection/configs/tf2/faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8.config (deflated 65%)
#   adding: content/models/research/object_detection/exporter_lib_v2.py (deflated 74%)
#   adding: content/models/research/object_detection/utils/ (stored 0%)
#   adding: content/models/research/object_detection/utils/object_detection_evaluation_test.py (deflated 89%)
#   adding: content/models/research/object_detection/utils/metrics.py (deflated 69%)
#   adding: content/models/research/object_detection/utils/np_mask_ops_test.py (deflated 74%)
#   adding: content/models/research/object_detection/utils/np_box_mask_list_ops.py (deflated 73%)
#   adding: content/models/research/object_detection/utils/label_map_util_test.py (deflated 84%)
#   adding: content/models/research/object_detection/utils/bifpn_utils.py (deflated 75%)
#   adding: content/models/research/object_detection/utils/np_box_list_ops.py (deflated 73%)
#   adding: content/models/research/object_detection/utils/static_shape.py (deflated 66%)
#   adding: content/models/research/object_detection/utils/target_assigner_utils.py (deflated 74%)
#   adding: content/models/research/object_detection/utils/learning_schedules.py (deflated 76%)
#   adding: content/models/research/object_detection/utils/per_image_evaluation.py (deflated 84%)
#   adding: content/models/research/object_detection/utils/config_util.py (deflated 81%)
#   adding: content/models/research/object_detection/utils/config_util_test.py (deflated 88%)
#   adding: content/models/research/object_detection/utils/context_manager.py (deflated 48%)
#   adding: content/models/research/object_detection/utils/variables_helper.py (deflated 67%)
#   adding: content/models/research/object_detection/utils/dataset_util.py (deflated 59%)
#   adding: content/models/research/object_detection/utils/tf_version.py (deflated 48%)
#   adding: content/models/research/object_detection/utils/static_shape_test.py (deflated 63%)
#   adding: content/models/research/object_detection/utils/colab_utils.py (deflated 76%)
#   adding: content/models/research/object_detection/utils/dataset_util_test.py (deflated 50%)
#   adding: content/models/research/object_detection/utils/vrd_evaluation.py (deflated 81%)
#   adding: content/models/research/object_detection/utils/category_util.py (deflated 56%)
#   adding: content/models/research/object_detection/utils/np_box_mask_list_ops_test.py (deflated 79%)
#   adding: content/models/research/object_detection/utils/target_assigner_utils_test.py (deflated 79%)
#   adding: content/models/research/object_detection/utils/np_box_mask_list_test.py (deflated 81%)
#   adding: content/models/research/object_detection/utils/model_util.py (deflated 64%)
#   adding: content/models/research/object_detection/utils/np_mask_ops.py (deflated 72%)
#   adding: content/models/research/object_detection/utils/test_utils_test.py (deflated 66%)
#   adding: content/models/research/object_detection/utils/ops_test.py (deflated 87%)
#   adding: content/models/research/object_detection/utils/np_box_list_ops_test.py (deflated 85%)
#   adding: content/models/research/object_detection/utils/np_box_list.py (deflated 64%)
#   adding: content/models/research/object_detection/utils/per_image_vrd_evaluation.py (deflated 78%)
#   adding: content/models/research/object_detection/utils/context_manager_test.py (deflated 49%)
#   adding: content/models/research/object_detection/utils/visualization_utils.py (deflated 79%)
#   adding: content/models/research/object_detection/utils/np_box_ops.py (deflated 67%)
#   adding: content/models/research/object_detection/utils/np_box_mask_list.py (deflated 57%)
#   adding: content/models/research/object_detection/utils/np_box_ops_test.py (deflated 65%)
#   adding: content/models/research/object_detection/utils/object_detection_evaluation.py (deflated 83%)
#   adding: content/models/research/object_detection/utils/json_utils_test.py (deflated 73%)
#   adding: content/models/research/object_detection/utils/shape_utils.py (deflated 71%)
#   adding: content/models/research/object_detection/utils/category_util_test.py (deflated 59%)
#   adding: content/models/research/object_detection/utils/test_case_test.py (deflated 67%)
#   adding: content/models/research/object_detection/utils/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/utils/test_utils.py (deflated 69%)
#   adding: content/models/research/object_detection/utils/model_util_tf2_test.py (deflated 56%)
#   adding: content/models/research/object_detection/utils/patch_ops.py (deflated 60%)
#   adding: content/models/research/object_detection/utils/json_utils.py (deflated 60%)
#   adding: content/models/research/object_detection/utils/per_image_vrd_evaluation_test.py (deflated 72%)
#   adding: content/models/research/object_detection/utils/variables_helper_tf1_test.py (deflated 82%)
#   adding: content/models/research/object_detection/utils/np_box_list_test.py (deflated 76%)
#   adding: content/models/research/object_detection/utils/shape_utils_test.py (deflated 83%)
#   adding: content/models/research/object_detection/utils/vrd_evaluation_test.py (deflated 86%)
#   adding: content/models/research/object_detection/utils/learning_schedules_test.py (deflated 80%)
#   adding: content/models/research/object_detection/utils/visualization_utils_test.py (deflated 81%)
#   adding: content/models/research/object_detection/utils/ops.py (deflated 74%)
#   adding: content/models/research/object_detection/utils/spatial_transform_ops_test.py (deflated 87%)
#   adding: content/models/research/object_detection/utils/autoaugment_utils.py (deflated 77%)
#   adding: content/models/research/object_detection/utils/metrics_test.py (deflated 77%)
#   adding: content/models/research/object_detection/utils/label_map_util.py (deflated 73%)
#   adding: content/models/research/object_detection/utils/test_case.py (deflated 80%)
#   adding: content/models/research/object_detection/utils/patch_ops_test.py (deflated 76%)
#   adding: content/models/research/object_detection/utils/per_image_evaluation_test.py (deflated 92%)
#   adding: content/models/research/object_detection/utils/spatial_transform_ops.py (deflated 76%)
#   adding: content/models/research/object_detection/packages/ (stored 0%)
#   adding: content/models/research/object_detection/packages/tf1/ (stored 0%)
#   adding: content/models/research/object_detection/packages/tf1/setup.py (deflated 56%)
#   adding: content/models/research/object_detection/packages/tf2/ (stored 0%)
#   adding: content/models/research/object_detection/packages/tf2/setup.py (deflated 54%)
#   adding: content/models/research/object_detection/inference/ (stored 0%)
#   adding: content/models/research/object_detection/inference/infer_detections.py (deflated 61%)
#   adding: content/models/research/object_detection/inference/detection_inference.py (deflated 71%)
#   adding: content/models/research/object_detection/inference/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/inference/detection_inference_tf1_test.py (deflated 73%)
#   adding: content/models/research/object_detection/exporter_tf1_test.py (deflated 90%)
#   adding: content/models/research/object_detection/model_main.py (deflated 65%)
#   adding: content/models/research/object_detection/builders/ (stored 0%)
#   adding: content/models/research/object_detection/builders/target_assigner_builder_test.py (deflated 56%)
#   adding: content/models/research/object_detection/builders/model_builder_test.py (deflated 80%)
#   adding: content/models/research/object_detection/builders/losses_builder.py (deflated 79%)
#   adding: content/models/research/object_detection/builders/calibration_builder.py (deflated 73%)
#   adding: content/models/research/object_detection/builders/box_coder_builder_test.py (deflated 80%)
#   adding: content/models/research/object_detection/builders/optimizer_builder_tf1_test.py (deflated 79%)
#   adding: content/models/research/object_detection/builders/model_builder.py (deflated 83%)
#   adding: content/models/research/object_detection/builders/region_similarity_calculator_builder_test.py (deflated 72%)
#   adding: content/models/research/object_detection/builders/graph_rewriter_builder_tf1_test.py (deflated 66%)
#   adding: content/models/research/object_detection/builders/anchor_generator_builder_test.py (deflated 85%)
#   adding: content/models/research/object_detection/builders/input_reader_builder.py (deflated 65%)
#   adding: content/models/research/object_detection/builders/dataset_builder.py (deflated 71%)
#   adding: content/models/research/object_detection/builders/anchor_generator_builder.py (deflated 75%)
#   adding: content/models/research/object_detection/builders/graph_rewriter_builder.py (deflated 55%)
#   adding: content/models/research/object_detection/builders/target_assigner_builder.py (deflated 60%)
#   adding: content/models/research/object_detection/builders/matcher_builder_test.py (deflated 74%)
#   adding: content/models/research/object_detection/builders/box_coder_builder.py (deflated 69%)
#   adding: content/models/research/object_detection/builders/dataset_builder_test.py (deflated 82%)
#   adding: content/models/research/object_detection/builders/calibration_builder_test.py (deflated 78%)
#   adding: content/models/research/object_detection/builders/box_predictor_builder.py (deflated 88%)
#   adding: content/models/research/object_detection/builders/hyperparams_builder_test.py (deflated 92%)
#   adding: content/models/research/object_detection/builders/matcher_builder.py (deflated 61%)
#   adding: content/models/research/object_detection/builders/model_builder_tf1_test.py (deflated 58%)
#   adding: content/models/research/object_detection/builders/decoder_builder_test.py (deflated 75%)
#   adding: content/models/research/object_detection/builders/optimizer_builder.py (deflated 79%)
#   adding: content/models/research/object_detection/builders/optimizer_builder_tf2_test.py (deflated 71%)
#   adding: content/models/research/object_detection/builders/input_reader_builder_tf1_test.py (deflated 80%)
#   adding: content/models/research/object_detection/builders/image_resizer_builder.py (deflated 73%)
#   adding: content/models/research/object_detection/builders/decoder_builder.py (deflated 67%)
#   adding: content/models/research/object_detection/builders/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/builders/losses_builder_test.py (deflated 90%)
#   adding: content/models/research/object_detection/builders/post_processing_builder.py (deflated 70%)
#   adding: content/models/research/object_detection/builders/post_processing_builder_test.py (deflated 82%)
#   adding: content/models/research/object_detection/builders/box_predictor_builder_test.py (deflated 90%)
#   adding: content/models/research/object_detection/builders/hyperparams_builder.py (deflated 75%)
#   adding: content/models/research/object_detection/builders/region_similarity_calculator_builder.py (deflated 67%)
#   adding: content/models/research/object_detection/builders/preprocessor_builder.py (deflated 81%)
#   adding: content/models/research/object_detection/builders/image_resizer_builder_test.py (deflated 82%)
#   adding: content/models/research/object_detection/builders/model_builder_tf2_test.py (deflated 81%)
#   adding: content/models/research/object_detection/builders/preprocessor_builder_test.py (deflated 89%)
#   adding: content/models/research/object_detection/inputs.py (deflated 81%)
#   adding: content/models/research/object_detection/export_tflite_graph_tf2.py (deflated 65%)
#   adding: content/models/research/object_detection/anchor_generators/ (stored 0%)
#   adding: content/models/research/object_detection/anchor_generators/multiple_grid_anchor_generator_test.py (deflated 83%)
#   adding: content/models/research/object_detection/anchor_generators/flexible_grid_anchor_generator.py (deflated 66%)
#   adding: content/models/research/object_detection/anchor_generators/flexible_grid_anchor_generator_test.py (deflated 85%)
#   adding: content/models/research/object_detection/anchor_generators/grid_anchor_generator.py (deflated 69%)
#   adding: content/models/research/object_detection/anchor_generators/multiple_grid_anchor_generator.py (deflated 73%)
#   adding: content/models/research/object_detection/anchor_generators/multiscale_grid_anchor_generator.py (deflated 65%)
#   adding: content/models/research/object_detection/anchor_generators/multiscale_grid_anchor_generator_test.py (deflated 85%)
#   adding: content/models/research/object_detection/anchor_generators/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/anchor_generators/grid_anchor_generator_test.py (deflated 74%)
#   adding: content/models/research/object_detection/metrics/ (stored 0%)
#   adding: content/models/research/object_detection/metrics/oid_vrd_challenge_evaluation_utils_test.py (deflated 78%)
#   adding: content/models/research/object_detection/metrics/coco_evaluation.py (deflated 85%)
#   adding: content/models/research/object_detection/metrics/calibration_evaluation.py (deflated 70%)
#   adding: content/models/research/object_detection/metrics/calibration_metrics_tf1_test.py (deflated 71%)
#   adding: content/models/research/object_detection/metrics/coco_tools_test.py (deflated 84%)
#   adding: content/models/research/object_detection/metrics/lvis_evaluation_test.py (deflated 78%)
#   adding: content/models/research/object_detection/metrics/oid_vrd_challenge_evaluation.py (deflated 69%)
#   adding: content/models/research/object_detection/metrics/tf_example_parser_test.py (deflated 79%)
#   adding: content/models/research/object_detection/metrics/oid_challenge_evaluation_utils.py (deflated 70%)
#   adding: content/models/research/object_detection/metrics/coco_evaluation_test.py (deflated 93%)
#   adding: content/models/research/object_detection/metrics/tf_example_parser.py (deflated 76%)
#   adding: content/models/research/object_detection/metrics/lvis_evaluation.py (deflated 77%)
#   adding: content/models/research/object_detection/metrics/lvis_tools_test.py (deflated 72%)
#   adding: content/models/research/object_detection/metrics/oid_challenge_evaluation.py (deflated 65%)
#   adding: content/models/research/object_detection/metrics/oid_challenge_evaluation_utils_test.py (deflated 82%)
#   adding: content/models/research/object_detection/metrics/calibration_evaluation_tf1_test.py (deflated 79%)
#   adding: content/models/research/object_detection/metrics/lvis_tools.py (deflated 70%)
#   adding: content/models/research/object_detection/metrics/io_utils.py (deflated 47%)
#   adding: content/models/research/object_detection/metrics/__init__.py (stored 0%)
# ...
#   adding: content/models/official/vision/evaluation/iou_test.py (deflated 75%)
#   adding: content/models/official/vision/evaluation/__init__.py (deflated 37%)
#   adding: content/models/official/vision/evaluation/coco_utils.py (deflated 73%)
#   adding: content/models/official/vision/evaluation/coco_utils_test.py (deflated 61%)
#   adding: content/models/official/vision/evaluation/panoptic_quality_evaluator.py (deflated 68%)
#   adding: content/models/official/vision/evaluation/iou.py (deflated 66%)
#   adding: content/models/official/vision/evaluation/segmentation_metrics_test.py (deflated 70%)
#   adding: content/models/official/vision/data/ (stored 0%)
#   adding: content/models/official/vision/data/process_coco_few_shot_json_files.py (deflated 58%)
#   adding: content/models/official/vision/data/create_coco_tf_record.py (deflated 75%)
#   adding: content/models/official/vision/data/tf_example_builder.py (deflated 82%)
#   adding: content/models/official/vision/data/fake_feature_generator.py (deflated 66%)
#   adding: content/models/official/vision/data/tf_example_feature_key.py (deflated 72%)
#   adding: content/models/official/vision/data/process_coco_panoptic.sh (deflated 73%)
#   adding: content/models/official/vision/data/tfrecord_lib.py (deflated 65%)
#   adding: content/models/official/vision/data/process_coco_few_shot.sh (deflated 72%)
#   adding: content/models/official/vision/data/__init__.py (deflated 37%)
#   adding: content/models/official/vision/data/image_utils.py (deflated 58%)
#   adding: content/models/official/vision/data/image_utils_test.py (deflated 70%)
#   adding: content/models/official/vision/data/tf_example_builder_test.py (deflated 88%)
#   adding: content/models/official/vision/data/tfrecord_lib_test.py (deflated 67%)
#   adding: content/models/official/vision/losses/ (stored 0%)
#   adding: content/models/official/vision/losses/focal_loss.py (deflated 55%)
#   adding: content/models/official/vision/losses/segmentation_losses_test.py (deflated 71%)
#   adding: content/models/official/vision/losses/loss_utils.py (deflated 52%)
#   adding: content/models/official/vision/losses/maskrcnn_losses.py (deflated 75%)
#   adding: content/models/official/vision/losses/__init__.py (deflated 37%)
#   adding: content/models/official/vision/losses/maskrcnn_losses_test.py (deflated 75%)
#   adding: content/models/official/vision/losses/segmentation_losses.py (deflated 72%)
#   adding: content/models/official/vision/losses/retinanet_losses.py (deflated 69%)
#   adding: content/models/official/vision/MODEL_GARDEN.md (deflated 79%)
#   adding: content/models/official/common/ (stored 0%)
#   adding: content/models/official/common/distribute_utils.py (deflated 68%)
#   adding: content/models/official/common/dataset_fn.py (deflated 64%)
#   adding: content/models/official/common/flags.py (deflated 60%)
#   adding: content/models/official/common/__init__.py (deflated 37%)
#   adding: content/models/official/common/streamz_counters.py (deflated 47%)
#   adding: content/models/official/common/distribute_utils_test.py (deflated 73%)
#   adding: content/models/official/common/registry_imports.py (deflated 42%)
#   adding: content/models/official/nightly_requirements.txt (deflated 36%)
#   adding: content/models/official/README-TPU.md (deflated 62%)
#   adding: content/models/LICENSE (deflated 65%)
#   adding: content/models/CODE_OF_CONDUCT.md (deflated 57%)
#   adding: content/models/docs/ (stored 0%)
#   adding: content/models/docs/orbit/ (stored 0%)
#   adding: content/models/docs/orbit/index.ipynb (deflated 76%)
#   adding: content/models/docs/nlp/ (stored 0%)
#   adding: content/models/docs/nlp/load_lm_ckpts.ipynb (deflated 84%)
#   adding: content/models/docs/nlp/fine_tune_bert.ipynb (deflated 78%)
#   adding: content/models/docs/nlp/decoding_api.ipynb (deflated 76%)
#   adding: content/models/docs/nlp/index.ipynb (deflated 79%)
#   adding: content/models/docs/nlp/_guide_toc.yaml (deflated 40%)
#   adding: content/models/docs/nlp/customize_encoder.ipynb (deflated 79%)
#   adding: content/models/docs/index.md (deflated 64%)
#   adding: content/models/docs/README.md (deflated 51%)
#   adding: content/models/docs/vision/ (stored 0%)
#   adding: content/models/docs/vision/_toc.yaml (deflated 61%)
#   adding: content/models/docs/vision/object_detection.ipynb (deflated 77%)
#   adding: content/models/docs/vision/semantic_segmentation.ipynb (deflated 76%)
#   adding: content/models/docs/vision/instance_segmentation.ipynb (deflated 77%)
#   adding: content/models/docs/vision/image_classification.ipynb (deflated 76%)
#   adding: content/models/.github/ (stored 0%)
#   adding: content/models/.github/bot_config.yml (deflated 44%)
#   adding: content/models/.github/ISSUE_TEMPLATE/ (stored 0%)
#   adding: content/models/.github/ISSUE_TEMPLATE/50-research-feature-request-issue.md (deflated 40%)
#   adding: content/models/.github/ISSUE_TEMPLATE/10-official-documentation-issue.md (deflated 37%)
#   adding: content/models/.github/ISSUE_TEMPLATE/config.yml (stored 0%)
#   adding: content/models/.github/ISSUE_TEMPLATE/20-official-feature-request-issue.md (deflated 40%)
#   adding: content/models/.github/ISSUE_TEMPLATE/30-research-bug-report-issue.md (deflated 50%)
#   adding: content/models/.github/ISSUE_TEMPLATE/00-official-bug-report-issue.md (deflated 50%)
#   adding: content/models/.github/ISSUE_TEMPLATE/40-research-documentation-issue.md (deflated 38%)
#   adding: content/models/.github/ISSUE_TEMPLATE/60-questions-help-issue.md (deflated 38%)
#   adding: content/models/.github/workflows/ (stored 0%)
#   adding: content/models/.github/workflows/ci.yml (deflated 53%)
#   adding: content/models/.github/workflows/stale.yaml (deflated 62%)
#   adding: content/models/.github/scripts/ (stored 0%)
#   adding: content/models/.github/scripts/pylint.sh (deflated 57%)
#   adding: content/models/.github/PULL_REQUEST_TEMPLATE.md (deflated 55%)
#   adding: content/models/.github/README_TEMPLATE.md (deflated 60%)
#   adding: content/models/ISSUES.md (deflated 49%)
#   adding: content/models/CONTRIBUTING.md (deflated 36%)
#   adding: content/models/.git/ (stored 0%)
#   adding: content/models/.git/config (deflated 34%)
#   adding: content/models/.git/refs/ (stored 0%)
#   adding: content/models/.git/refs/remotes/ (stored 0%)
#   adding: content/models/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/models/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/models/.git/refs/heads/ (stored 0%)
#   adding: content/models/.git/refs/heads/master (stored 0%)
#   adding: content/models/.git/refs/tags/ (stored 0%)
#   adding: content/models/.git/index (deflated 66%)
#   adding: content/models/.git/logs/ (stored 0%)
#   adding: content/models/.git/logs/refs/ (stored 0%)
#   adding: content/models/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/models/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/models/.git/logs/refs/remotes/origin/HEAD (deflated 29%)
#   adding: content/models/.git/logs/refs/heads/ (stored 0%)
#   adding: content/models/.git/logs/refs/heads/master (deflated 29%)
#   adding: content/models/.git/logs/HEAD (deflated 29%)
#   adding: content/models/.git/info/ (stored 0%)
#   adding: content/models/.git/info/exclude (deflated 28%)
#   adding: content/models/.git/HEAD (stored 0%)
#   adding: content/models/.git/hooks/ (stored 0%)
#   adding: content/models/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/models/.git/hooks/pre-push.sample (deflated 50%)
#   adding: content/models/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/models/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/models/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/models/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/models/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/models/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/models/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/models/.git/hooks/fsmonitor-watchman.sample (deflated 52%)
#   adding: content/models/.git/hooks/update.sample (deflated 68%)
#   adding: content/models/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/models/.git/objects/ (stored 0%)
#   adding: content/models/.git/objects/info/ (stored 0%)
#   adding: content/models/.git/objects/pack/ (stored 0%)
#   adding: content/models/.git/objects/pack/pack-1bf2599b9214a232aeddd2f8d6d011b7c364d252.pack (deflated 0%)
#   adding: content/models/.git/objects/pack/pack-1bf2599b9214a232aeddd2f8d6d011b7c364d252.idx (deflated 1%)
#   adding: content/models/.git/description (deflated 14%)
#   adding: content/models/.git/packed-refs (deflated 62%)
#   adding: content/models/.git/branches/ (stored 0%)
#   adding: content/models/community/ (stored 0%)
#   adding: content/models/community/README.md (deflated 78%)
#   adding: content/training_demo/ (stored 0%)
#   adding: content/training_demo/.ipynb_checkpoints/ (stored 0%)
#   adding: content/training_demo/export_tflite_graph_tf2.py (deflated 66%)
#   adding: content/training_demo/annotations/ (stored 0%)
#   adding: content/training_demo/annotations/train.record (deflated 0%)
#   adding: content/training_demo/annotations/test.record (deflated 0%)
#   adding: content/training_demo/annotations/label_map.pbtxt (deflated 37%)
#   adding: content/training_demo/model_main_tf2.py (deflated 62%)
#   adding: content/training_demo/pre_trained_models/ (stored 0%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz (deflated 0%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/ (stored 0%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/pipeline.config (deflated 67%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/ (stored 0%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/ (stored 0%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.index (deflated 18%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/assets/ (stored 0%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/saved_model.pb (deflated 94%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/ (stored 0%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.index (deflated 18%)
#   adding: content/training_demo/pre_trained_models/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/checkpoint (deflated 42%)
#   adding: content/training_demo/exporter_main_v2.py (deflated 68%)
#   adding: content/training_demo/models/ (stored 0%)
#   adding: content/training_demo/models/.ipynb_checkpoints/ (stored 0%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/ (stored 0%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/ckpt-2.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/pipeline.config (deflated 67%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/ckpt-3.index (deflated 84%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/ckpt-1.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/train/ (stored 0%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/train/events.out.tfevents.1684428203.2ec921088f5a.17089.0.v2 (deflated 1%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/train/events.out.tfevents.1684427850.2ec921088f5a.15559.0.v2 (deflated 5%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/ckpt-2.index (deflated 84%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/checkpoint (deflated 68%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/ckpt-4.index (deflated 84%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/ckpt-4.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/ckpt-1.index (deflated 84%)
#   adding: content/training_demo/models/my_ssd_resnet101_v1_fpn/ckpt-3.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/images/ (stored 0%)
#   adding: content/training_demo/images/.ipynb_checkpoints/ (stored 0%)
#   adding: content/training_demo/images/train/ (stored 0%)
#   adding: content/training_demo/images/train/image17.jpg (deflated 0%)
#   adding: content/training_demo/images/train/image17.xml (deflated 66%)
#   adding: content/training_demo/images/train/image1.xml (deflated 74%)
#   adding: content/training_demo/images/train/image1.jpg (deflated 1%)
#   adding: content/training_demo/images/train/image3.xml (deflated 77%)
#   adding: content/training_demo/images/train/image18.jpg (deflated 0%)
#   adding: content/training_demo/images/train/image16.xml (deflated 66%)
#   adding: content/training_demo/images/train/image9.xml (deflated 77%)
#   adding: content/training_demo/images/train/image16.jpg (deflated 0%)
#   adding: content/training_demo/images/train/image18.xml (deflated 66%)
#   adding: content/training_demo/images/train/image9.jpg (deflated 0%)
#   adding: content/training_demo/images/train/image3.jpg (deflated 0%)
#   adding: content/training_demo/images/test/ (stored 0%)
#   adding: content/training_demo/images/test/image25.jpg (deflated 0%)
#   adding: content/training_demo/images/test/image24.jpg (deflated 0%)
#   adding: content/training_demo/images/test/image39.xml (deflated 48%)
#   adding: content/training_demo/images/test/image25.xml (deflated 48%)
#   adding: content/training_demo/images/test/image39.jpg (deflated 0%)
#   adding: content/training_demo/images/test/image24.xml (deflated 48%)
#   adding: content/training_demo/generate_tfrecord.py (deflated 69%)
#   adding: content/training_demo/exported_models/ (stored 0%)
#   adding: content/training_demo/exported_models/.ipynb_checkpoints/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/pipeline.config (deflated 68%)
#   adding: content/training_demo/exported_models/my_model/saved_model/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/saved_model/variables/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/saved_model/variables/variables.index (deflated 81%)
#   adding: content/training_demo/exported_models/my_model/saved_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/exported_models/my_model/saved_model/assets/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/saved_model/saved_model.pb (deflated 93%)
#   adding: content/training_demo/exported_models/my_model/saved_model/fingerprint.pb (stored 0%)
#   adding: content/training_demo/exported_models/my_model/checkpoint/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/checkpoint/ckpt-0.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/exported_models/my_model/checkpoint/ckpt-0.index (deflated 82%)
#   adding: content/training_demo/exported_models/my_model/checkpoint/checkpoint (deflated 41%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)

# %%
from google.colab import files

# %%
files.download('/content/TensorFlowObjectDetection.zip')

# %%
# !zip -r /content/trained_model.zip /content/training_demo/exported_models/
# Out:
#   adding: content/training_demo/exported_models/ (stored 0%)
#   adding: content/training_demo/exported_models/.ipynb_checkpoints/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/pipeline.config (deflated 68%)
#   adding: content/training_demo/exported_models/my_model/saved_model/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/saved_model/variables/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/saved_model/variables/variables.index (deflated 81%)
#   adding: content/training_demo/exported_models/my_model/saved_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/exported_models/my_model/saved_model/assets/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/saved_model/saved_model.pb (deflated 93%)
#   adding: content/training_demo/exported_models/my_model/saved_model/fingerprint.pb (stored 0%)
#   adding: content/training_demo/exported_models/my_model/checkpoint/ (stored 0%)
#   adding: content/training_demo/exported_models/my_model/checkpoint/ckpt-0.data-00000-of-00001 (deflated 7%)
#   adding: content/training_demo/exported_models/my_model/checkpoint/ckpt-0.index (deflated 82%)
#   adding: content/training_demo/exported_models/my_model/checkpoint/checkpoint (deflated 41%)

# %%
files.download('/content/trained_model.zip')
